# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D



import sklearn


import numpy as np

import scipy as sp
from scipy.stats import spearmanr

import pandas as pd
from pandas import Series, DataFrame


import seaborn as sns

df=pd.read_csv("H:\codes\Cse465\indian_liver_patient.csv")
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  female              0.7               0.1                   187
# 1   62    male             10.9               5.5                   699
# 2   62    male              7.3               4.1                   490
# 3   58    male              1.0               0.4                   182
# 4   72    male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio Dataset
# 0      3.3                        0.90     yes
# ...

# %%
df.shape
# Out:
# (583, 11)

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
df_sub = df[ df['Dataset'] == 'no' ]         #number of instances with 1000 suicides
print(df_sub.shape)
# Out:
# (167, 11)

# %%
df.max()
# Out:
# Age                             90
# Gender                        male
# Total_Bilirubin                 75
# Direct_Bilirubin              19.7
# Alkaline_Phosphotase          2110
# Alamine_Aminotransferase      2000
# Aspartate_Aminotransferase    4929
# Total_Protiens                 9.6
# Albumin                        5.5
# Albumin_and_Globulin_Ratio     2.8
# Dataset                        yes
# dtype: object

# %%
plt.xlabel("Total_Bilirubin")
plt.ylabel("Direct_Bilirubin")
plt.plot(df.Total_Bilirubin,df.Direct_Bilirubin)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.xlabel("Total_Bilirubin")
plt.ylabel("Gender")
plt.plot(df.Total_Bilirubin,df.Gender)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
corr=df.corr()

# %%
plt.figure(figsize=(20,10)) 
sns.heatmap(corr,cmap="Blues",annot=True)

# %%
plt.rcParams['figure.figsize']=(10,10)

# %%
sns.pairplot(df)
# Out:
# c:\users\farhanur rahaman\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\histograms.py:829: RuntimeWarning: invalid value encountered in greater_equal
#   # is 2x as fast) and it results in a memory footprint 3x lower in the
# c:\users\farhanur rahaman\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\histograms.py:830: RuntimeWarning: invalid value encountered in less_equal
#   # limit of large arrays.

# %%
sns.scatterplot(x="Albumin", y="Albumin_and_Globulin_Ratio",color='green',data=df);
plt.show()

# %%
sns.scatterplot(x="Total_Bilirubin", y="Direct_Bilirubin",color='Blue',data=df);
plt.show()

# %%
sns.scatterplot(x="Alamine_Aminotransferase", y="Aspartate_Aminotransferase",color='Black',data=df);
plt.show()

# %%
df['Dataset'].value_counts()
# Out:
# yes    416
# no     167
# Name: Dataset, dtype: int64

# %%
df.max()
# Out:
# Age                             90
# Gender                        male
# Total_Bilirubin                 75
# Direct_Bilirubin              19.7
# Alkaline_Phosphotase          2110
# Alamine_Aminotransferase      2000
# Aspartate_Aminotransferase    4929
# Total_Protiens                 9.6
# Albumin                        5.5
# Albumin_and_Globulin_Ratio     2.8
# Dataset                        yes
# dtype: object

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Dataset                        object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Dataset                       0
# dtype: int64

# %%
df['Albumin_and_Globulin_Ratio'].mean()
df=df.fillna(0.94)

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Dataset                       0
# dtype: int64

# %%
count_classes = pd.value_counts(df['Dataset'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the Dataset")
plt.xlabel("Dataset")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes = pd.value_counts(df['Gender'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the Gender")
plt.xlabel("Gender")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
X=df[['Age','Gender','Direct_Bilirubin',
       'Alkaline_Phosphotase', 'Alamine_Aminotransferase',
        'Total_Protiens', 'Albumin']]
X=df.drop("Dataset",axis=1)
y=df["Dataset"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test, = train_test_split(X,y,test_size=0.2, random_state=123)

# %%
from sklearn.linear_model import LogisticRegression

from sklearn.datasets import make_blobs

# %%
model=LogisticRegression(multi_class='multinomial',solver='lbfgs')

# %%
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-626-d768f88d541e> in <module>
# ----> 1 model.fit(X_train, y_train)
#
# c:\users\farhanur rahaman\appdata\local\programs\python\python36\lib\site-packages\sklearn\linear_model\logistic.py in fit(self, X, y, sample_weight)
#    1530
#    1531         X, y = check_X_y(X, y, accept_sparse='csr', dtype=_dtype, order="C",
# -> 1532                          accept_large_sparse=solver != 'liblinear')
#    1533         check_classification_targets(y)
#    1534         self.classes_ = np.unique(y)
#
# c:\users\farhanur rahaman\appdata\local\programs\python\python36\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
# ...

# %%
pred=model.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_test,pred)
# Out:
# array([[ 7, 30],
#        [ 2, 78]], dtype=int64)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,pred)
# Out:
# 0.7264957264957265

# %%
pred=model.predict(X_train)
accuracy_score(y_train,pred)
# Out:
# 0.723175965665236
