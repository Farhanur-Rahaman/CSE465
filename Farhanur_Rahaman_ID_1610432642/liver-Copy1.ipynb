# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

from mpl_toolkits.mplot3d import Axes3D



import sklearn


import numpy as np

import scipy as sp
from scipy.stats import spearmanr

import pandas as pd
from pandas import Series, DataFrame


import seaborn as sns

df=pd.read_csv("H:\codes\Cse465\indian_liver_patient.csv")
df.head()
# Out:
#    Age  Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65  female              0.7               0.1                   187
# 1   62    male             10.9               5.5                   699
# 2   62    male              7.3               4.1                   490
# 3   58    male              1.0               0.4                   182
# 4   72    male              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Result
# 0      3.3                        0.90       1
# ...

# %%
df['Gender'].replace(['female','male'],['0','1'], inplace=True)
df.head()
# Out:
#    Age Gender  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# 0   65      0              0.7               0.1                   187
# 1   62      1             10.9               5.5                   699
# 2   62      1              7.3               4.1                   490
# 3   58      1              1.0               0.4                   182
# 4   72      1              3.9               2.0                   195
#
#    Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# 0                        16                          18             6.8
# 1                        64                         100             7.5
# 2                        60                          68             7.0
# 3                        14                          20             6.8
# 4                        27                          59             7.3
#
#    Albumin  Albumin_and_Globulin_Ratio  Result
# 0      3.3                        0.90       1
# ...

# %%
df.shape
# Out:
# (583, 11)

# %%
df.describe()
# Out:
#               Age  Total_Bilirubin  Direct_Bilirubin  Alkaline_Phosphotase  \
# count  583.000000       583.000000        583.000000            583.000000
# mean    44.746141         3.298799          1.486106            290.576329
# std     16.189833         6.209522          2.808498            242.937989
# min      4.000000         0.400000          0.100000             63.000000
# 25%     33.000000         0.800000          0.200000            175.500000
# 50%     45.000000         1.000000          0.300000            208.000000
# 75%     58.000000         2.600000          1.300000            298.000000
# max     90.000000        75.000000         19.700000           2110.000000
#
#        Alamine_Aminotransferase  Aspartate_Aminotransferase  Total_Protiens  \
# count                583.000000                  583.000000      583.000000
# mean                  80.713551                  109.910806        6.483190
# ...

# %%
df_sub = df[ df['Result'] == 'no' ]         #number of instances with 1000 suicides
print(df_sub.shape)
# Out:
# (0, 11)
# c:\users\farhanur rahaman\appdata\local\programs\python\python36\lib\site-packages\pandas\core\ops\__init__.py:1115: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = method(y)

# %%
df.max()
# Out:
# Age                             90.0
# Gender                           1.0
# Total_Bilirubin                 75.0
# Direct_Bilirubin                19.7
# Alkaline_Phosphotase          2110.0
# Alamine_Aminotransferase      2000.0
# Aspartate_Aminotransferase    4929.0
# Total_Protiens                   9.6
# Albumin                          5.5
# Albumin_and_Globulin_Ratio       2.8
# Result                           2.0
# dtype: float64

# %%
plt.xlabel("Total_Bilirubin")
plt.ylabel("Direct_Bilirubin")
plt.plot(df.Total_Bilirubin,df.Direct_Bilirubin)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.xlabel("Total_Bilirubin")
plt.ylabel("Gender")
plt.plot(df.Total_Bilirubin,df.Gender)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
corr=df.corr()

# %%
plt.figure(figsize=(40,20)) 
sns.heatmap(corr,cmap="Blues",annot=True)

# %%
plt.rcParams['figure.figsize']=(11,11)

# %%
sns.pairplot(df)
# Out:
# c:\users\farhanur rahaman\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\histograms.py:839: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# c:\users\farhanur rahaman\appdata\local\programs\python\python36\lib\site-packages\numpy\lib\histograms.py:840: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
sns.scatterplot(x="Albumin", y="Albumin_and_Globulin_Ratio",color='green',data=df);
plt.show()

# %%
sns.scatterplot(x="Albumin", y="Total_Protiens",color='green',data=df);
plt.show()

# %%
sns.scatterplot(x="Total_Bilirubin", y="Direct_Bilirubin",color='Blue',data=df);
plt.show()

# %%
sns.scatterplot(x="Alamine_Aminotransferase", y="Aspartate_Aminotransferase",color='Black',data=df);
plt.show()

# %%
df['Result'].value_counts()
# Out:
# 1    416
# 2    167
# Name: Result, dtype: int64

# %%
df.max()
# Out:
# Age                             90.0
# Gender                           1.0
# Total_Bilirubin                 75.0
# Direct_Bilirubin                19.7
# Alkaline_Phosphotase          2110.0
# Alamine_Aminotransferase      2000.0
# Aspartate_Aminotransferase    4929.0
# Total_Protiens                   9.6
# Albumin                          5.5
# Albumin_and_Globulin_Ratio       2.8
# Result                           2.0
# dtype: float64

# %%
df.dtypes
# Out:
# Age                             int64
# Gender                         object
# Total_Bilirubin               float64
# Direct_Bilirubin              float64
# Alkaline_Phosphotase            int64
# Alamine_Aminotransferase        int64
# Aspartate_Aminotransferase      int64
# Total_Protiens                float64
# Albumin                       float64
# Albumin_and_Globulin_Ratio    float64
# Result                          int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    4
# Result                        0
# dtype: int64

# %%
df['Albumin_and_Globulin_Ratio'].mean()
df=df.fillna(0.94)

# %%
df.isnull().sum()
# Out:
# Age                           0
# Gender                        0
# Total_Bilirubin               0
# Direct_Bilirubin              0
# Alkaline_Phosphotase          0
# Alamine_Aminotransferase      0
# Aspartate_Aminotransferase    0
# Total_Protiens                0
# Albumin                       0
# Albumin_and_Globulin_Ratio    0
# Result                        0
# dtype: int64

# %%
#histogram of result
count_classes = pd.value_counts(df['Result'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the Result")
plt.xlabel("Result")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes = pd.value_counts(df['Age'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the age")
plt.xlabel("Result")
# Out:
# Text(0.5, 0, 'Result')

# %%
count_classes = pd.value_counts(df['Gender'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the Gender")
plt.xlabel("Gender")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes = pd.value_counts(df['Total_Bilirubin'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the Total_Bilirubin")
plt.xlabel("Total_Bilirubin")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes = pd.value_counts(df['Direct_Bilirubin'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the Direct_Bilirubin")
plt.xlabel("Direct_Bilirubin")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes = pd.value_counts(df['Alamine_Aminotransferase'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the Alamine_Aminotransferase")
plt.xlabel("Alamine_Aminotransferase")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes = pd.value_counts(df['Aspartate_Aminotransferase'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the Aspartate_Aminotransferase")
plt.xlabel("Aspartate_Aminotransferase")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes = pd.value_counts(df['Albumin'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the Albumin")
plt.xlabel("Albumin")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %%
count_classes = pd.value_counts(df['Total_Protiens'], sort = True).sort_index()
count_classes.plot(kind = 'bar')
plt.title("Histogram for the Total_Protiens")
plt.xlabel("Total_Protiens")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
